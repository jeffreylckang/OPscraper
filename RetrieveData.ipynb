# %% [markdown]
# The line below will run the scraper for OddsPortal to retrieve the data.

# %%
# %run FinalScraper.py
# Out:
# /Users/jeffreykang/scrapeOP
# Data will be saved in the following directory: /Users/jeffreykang/scrapeOP
# Starting to scrape season 2022-2023
# 28 pages to scrape
# Starting on page 1: https://www.oddsportal.com/basketball/usa/nba-2022-2023/results/
# Pausing for 3.28 seconds...
# Found 50 game divs.
# game_id for 1: CdcbfwIf
# Pausing for 2.71 seconds...
# Navigating to the game link: https://www.oddsportal.com/basketball/usa/nba-2022-2023/denver-nuggets-miami-heat-CdcbfwIf/
# Processing game CdcbfwIf
# Pausing for 1.05 seconds...
# Data from game 1 collected
# Pausing for 4.84 seconds...
# Found 50 game divs.
# game_id for 2: McoBe1r8
# Pausing for 2.28 seconds...
# Navigating to the game link: https://www.oddsportal.com/basketball/usa/nba-2022-2023/miami-heat-denver-nuggets-McoBe1r8/
# Processing game McoBe1r8
# Pausing for 2.25 seconds...
# Data from game 2 collected
# Pausing for 2.42 seconds...
# Found 50 game divs.
# game_id for 3: 8fcTWH57
# Pausing for 2.01 seconds...
# ...

# %% [markdown]
# https://www.oddsportal.com/football/england/premier-league-2020-2021/wolves-leicester-AZqnPSmg/#1X2;2
# https://www.oddsportal.com/football/england/premier-league-2020-2021/fulham-arsenal-tz25uH2H/#1X2;2
#
# add these to data because code did not recrod these for some reason
#
# https://www.oddsportal.com/football/england/premier-league-2023-2024/luton-nottingham-rkLD46En/#1X2;2
# check this one as well
